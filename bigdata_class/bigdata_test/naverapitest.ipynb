# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import ssl
client_id = "VVrSb7DXLYUr2IRlQNSU"
client_secret = "pJSQFrP13Z"
encText = urllib.parse.quote("상명대학교")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
context = ssl._create_unverified_context()
response = urllib.request.urlopen(request, context=context) #리퀴스트를 참조해야됨!
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 30 Mar 2023 20:29:03 +0900",
# 	"total":62603,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"젠트라X 새똥테러 + <b>상명대학교<\/b> 천안캠퍼스",
# 			"link":"https:\/\/www.tisdory.com\/3989",
# 			"description":"여튼 세차를 마치고 또 옛 추억에 젖어 <b>상명대학교<\/b> 천안캠퍼스를 한바퀴 둘러보고 오기로 합니다. 역말오거리에서 북일고등학교를 거쳐 단국대학교 가는 길로 나가다가 단국대학교 진입 전 우회전 해서... ",
# 			"bloggername":"티스도리닷컴 :: 티스도리닷컴",
# 			"bloggerlink":"https:\/\/www.tisdory.com\/",
# 			"postdate":"20211005"
# 		},
# 		{
# 			"title":"<b>상명대학교<\/b> 사진 영상 미디어... 인터뷰_ <b>상명대학교<\/b> 1년 사용... ",
# 			"link":"https:\/\/blog.naver.com\/underphoto\/223013256234",
# 			"description":"<b>상명대학교<\/b>에서 1년을 공부하고 인터뷰를 촬영하였기 때문에 <b>상명대학교<\/b>의 대학교 생활에 대한 이야기도 함께 담았습니다. 지금까지 인터뷰한 학생 중 말을 가장 많이 해서 부원장님이 편집하는데 가장 오랜... ",
# 			"bloggername":"상상사진학원",
# 			"bloggerlink":"blog.naver.com\/underphoto",
# 			"postdate":"20230213"
# 		},
# 		{
# 			"title":"<b>상명대학교<\/b> 편입 집에서 일반 학사 학력 맞추는 방법",
# 			"link":"https:\/\/blog.naver.com\/thrill4481\/223044929138",
# 			"description":"안녕하세요 <b>상명대학교<\/b> 편입 준비할때 집에서 일반과 학사 지원학력을 맞춘 입학생입니다. 대학을... 저희 가족중에 <b>상명대학교<\/b>를 다니는 언니가 있는데요. 공부를 못하는걸로 알고있었는데 뜬금없이... ",
# 			"bloggername":"하얀 그림자",
# 			"bloggerlink":"blog.naver.com\/thrill4481",
# 			"postdate":"20230315"
# 		},
# 		{
# 			"title":"<b>상명대학교<\/b> 편입 재수보다 효과적인 입시방법",
# 			"link":"https:\/\/blog.naver.com\/smhr4\/223035491266",
# 			"description":"모집요강 <b>상명대학교<\/b>는 예체능계열을 제외한 대부분 학과들이 공인영어성적 100%만 반영해 다른 대학교... 통해 상명대 편입을 할 수 있도록 돕고 있답니다 인 서울권 대학이라 합격 할 수 있을 까 걱정했던... ",
# 			"bloggername":"매머드연구소",
# 			"bloggerlink":"blog.naver.com\/smhr4",
# 			"postdate":"20230305"
# 		},
# 		{
# 			"title":"[입시결과] 2023학년도 \/ <b>상명대학교<\/b> 천안캠퍼스 \/ 수시등급... ",
# 			"link":"https:\/\/blog.naver.com\/duxijin\/223056648845",
# 			"description":"2023학년도 <b>상명대학교<\/b> 천안캠퍼스 \/ 수시모집 \/ 학생부종합(상명인재전형)\/ 최종등록자 성적현황 수능 최저학력기준 - 없음 전형방법 1단계(3배수 선발) - 서류평가 100% 2단계 - 서류평가 70% + 면접고사 30... ",
# 			"bloggername":"독학대세학원 대세입시컨설팅 이감오프 간쓸개",
# 			"bloggerlink":"blog.naver.com\/duxijin",
# 			"postdate":"20230327"
# 		},
# 		{
# 			"title":"2023 상명대, <b>상명대학교<\/b> 합격을 축하합니다!! :)ㅣ[분당... ",
# 			"link":"https:\/\/blog.naver.com\/queenmade\/223015691014",
# 			"description":"<b>상명대학교<\/b> 합격생입니다. ⸜( ˙ ˘ ˙)⸝♡ 일단! 상명대 합격생의 인터뷰와 합격작을 보기 전.. 저번 포스팅에서는 청강대 합격생의 인터뷰와 재현작 일부분을 포스팅 했는데요! 관심있으신 분들은 아래 링크... ",
# 			"bloggername":"센스 애니툰 미술학원 고등부",
# 			"bloggerlink":"blog.naver.com\/queenmade",
# 			"postdate":"20230214"
# 		},
# 		{
# 			"title":"<b>상명대학교<\/b> 2023학년도 정시 \/ 학생부종합(특성화고 등을... ",
# 			"link":"https:\/\/blog.naver.com\/bosungabi\/222976501094",
# 			"description":"2023학년도 <b>상명대학교<\/b> 정시 학생부종합(특성화고 등을 졸업한 재직자전형) 모집요강 입니다. 자세한... 29(목)] 당시 재직 중이어야 하며, 군 의무복무(대체복무 포함) 중인 자는 지원 불가함 [<b>상명대학교<\/b>교... ",
# 			"bloggername":"수험서의 명가 씨마스",
# 			"bloggerlink":"blog.naver.com\/bosungabi",
# 			"postdate":"20230106"
# 		},
# 		{
# 			"title":"2023 상명대 수시등급 - <b>상명대학교<\/b> 서울·천안캠퍼스 내신등급... ",
# 			"link":"https:\/\/blog.naver.com\/myappkorea\/223051405024",
# 			"description":"2023 상명대 수시등급 2023 <b>상명대학교<\/b> 서울캠퍼스 천안캠퍼스 미대, 문과, 이과 입시결과 <b>상명대학교<\/b> 수능최저, 수시등급, 경쟁률, 모집인원 수능최저등급 여부 상명대 미술학부 SW융합학부 상명대 디자인학부... ",
# 			"bloggername":"미대입시닷컴 미대입시 입시미술",
# 			"bloggerlink":"blog.naver.com\/myappkorea",
# 			"postdate":"20230321"
# 		},
# 		{
# 			"title":"2024학년도 <b>상명대학교<\/b> 수시\/정시모집 입시요강... ",
# 			"link":"https:\/\/blog.naver.com\/ddgreensum\/223041538400",
# 			"description":"출처: <b>상명대학교<\/b> 입학처 상명대 미대에는 다양한 전형으로 신입생을 선발하는데요. 실기를 준비했다면 실기전형, 생기부 상태가 좋고 면접 대비에 강점이 있다면 학생부종합전형, 내신성적이 높다면... ",
# 			"bloggername":"광주 애니섬 만화학원 V 그린섬미술학원",
# 			"bloggerlink":"blog.naver.com\/ddgreensum",
# 			"postdate":"20230311"
# 		},
# 		{
# 			"title":"2024년도 <b>상명대학교<\/b> 천안캠퍼스 스포츠융합학부 수시\/정시... ",
# 			"link":"https:\/\/blog.naver.com\/nsportsn\/223060098288",
# 			"description":"오늘은 <b>상명대학교<\/b> 스포츠융합학부 2024학년도 전형계획에 대해 알아보겠습니다! ● 모집인원 ▶ 수시모집 학생부종합 상명인재전형 8명 선발 실기\/실적 실기전형 38명 선발 ▶ 정시모집 '정시 나군... ",
# 			"bloggername":"인천 부평 타임 체대입시",
# 			"bloggerlink":"blog.naver.com\/nsportsn",
# 			"postdate":"20230330"
# 		}
# 	]
# }
